# %%
import pandas as pd
import numpy as np
import sqlalchemy
import pyodbc
import datetime
import psycopg2
from sqlalchemy import create_engine
# Out:
# /home/iceman/PycharmProjects/Django-API-Testing/djangovenv/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
postgres_ip = "192.168.0.101:5432" 
engine_tpo = create_engine('postgresql://syedmisbah:test123@192.168.0.101:5432/vision')

# %%
dataset_example=pd.read_csv("Datasets/Dataset_example.csv")

# %%
dataset_example
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>CustomerID</th>
#       <th>Account</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Earl</td>
#       <td>179</td>
#       <td>Airbus</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Keith</td>
#       <td>24100</td>
#       <td>Airbus</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Raymond</td>
#       <td>59609</td>
#       <td>Boeing</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Lily</td>
#       <td>68021</td>
#       <td>Boeing</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>May</td>
# ...

# %%
 dataset_example.to_sql('Forecasting_basetable', engine_tpo,if_exists='append',index=False)
